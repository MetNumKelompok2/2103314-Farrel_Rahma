# %% [markdown]
# # **Interpolasi**

# %% [markdown]
# **Interpolasi Newton**

# %%
# Nama  : Farrel Rahma Aliyya
# NIM   : 2103314
# Interpolasi Newton

# untuk import library
import numpy as np

jumlahData = int(input('Masukan jumlah data x dan y: '))
nilaiX = np.zeros((jumlahData))
nilaiY = np.zeros((jumlahData, jumlahData))


print('Masukan data x dan y: ')
for i in range(jumlahData):
    nilaiX[i] = float(input('nilaiX(' + str(i) + ') = '))
    nilaiY[i][0] = float(input('nilaiY(' + str(i) + ') = '))
    

inputX = input('Masukkan nilai x yang ingin diketahui: ')
inputX = float(inputX)

for i in range(1, jumlahData):
    for j in range(0, jumlahData-i):
        nilaiY[j][i] = (nilaiY[j + 1, i - 1] - nilaiY[j, i - 1])/(nilaiX[j+i] - x[j])

print('\n============================================ TABEL SELISIH - TERBAGI==============================================');
for i in range(0, jumlahData):
    print('%0.2f' % (x[i]), end='')
    for j in range(0, jumlahData - i):
        print('\t\t%0.6f' % (nilaiY[i][j]), end='')
    print()
print('=================================================================================================================');

p = nilaiY[0,0]
for i in range (1, jumlahData):
    a = nilaiY[0,i]
    for j in range(0, i):
        a = a * (inputX-x[j])
    p = p+a
print('Nilai hampiran dari data tersebut adalah %0.6f' % p)
# Out:
# Masukan data x dan y:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 24
#      22 for i in range(1, jumlahData):
#      23     for j in range(0, jumlahData-i):
# ---> 24         nilaiY[j][i] = (nilaiY[j + 1, i - 1] - nilaiY[j, i - 1])/(nilaiX[j+i] - x[j])
#      26 print('\n============================================TABEL SELISIH - TERBAGI==============================================');
#      27 for i in range(0, jumlahData):
#
# NameError: name 'x' is not defined
